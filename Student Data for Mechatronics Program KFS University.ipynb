# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Mechatronics_Data.csv')

df
# Out:
#      code                                            course  level  \
# 0   40102                           Engineering Mechanics 1    0.0
# 1   40105                           Production Technology 1    0.0
# 2   40106                           Engineering Mechanics 2    0.0
# 3   40501                        Engineering  Mathematics 1    0.0
# 4   40502                             Engineering Physics 1    0.0
# 5   40503                             Engineering Chemistry    0.0
# 6   40504                        Engineering  Mathematics 2    0.0
# 7   40505                             Engineering Physics 2    0.0
# 8   40101                                             CAD 1    0.0
# 9   40103                                             CAD 2    0.0
# 10  40104                               Engineering History    0.0
# 11  40144                                 Technical English    0.0
# 12  40108                           Engineering Mechanics 3    1.0
# ...

# %%
#Now the courses'codes are string
df.code=df.code.astype(dtype=str,copy=False,errors='ignore')

df.code=df.code.infer_objects()
for x in range(0,len(df.code)):
    df.code[x]=df.code[x].zfill(5)
# Out:
# <ipython-input-188-6c30ecb977db>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.code[x]=df.code[x].zfill(5)

# %%
df
# Out:
#      code                                            course  level  \
# 0   40102                           Engineering Mechanics 1    0.0
# 1   40105                           Production Technology 1    0.0
# 2   40106                           Engineering Mechanics 2    0.0
# 3   40501                        Engineering  Mathematics 1    0.0
# 4   40502                             Engineering Physics 1    0.0
# 5   40503                             Engineering Chemistry    0.0
# 6   40504                        Engineering  Mathematics 2    0.0
# 7   40505                             Engineering Physics 2    0.0
# 8   40101                                             CAD 1    0.0
# 9   40103                                             CAD 2    0.0
# 10  40104                               Engineering History    0.0
# 11  40144                                 Technical English    0.0
# 12  40108                           Engineering Mechanics 3    1.0
# ...

# %% [markdown]
# The courses I have taken so far

# %%
# df.loc[df.code=='40109','if_taken']= True
# df.loc[df.code=='40116','if_taken']= True
# df.loc[df.code=='40147','if_taken']= True
# df.loc[df.code=='40117','if_taken']= True
# df.loc[df.code=='40118','if_taken']= True
# df.loc[df.code=='40216','if_taken']= True
# df.loc[df.code=='40205','if_taken']= True

# %% [markdown]
# GPA for each course

# %%
# df.loc[df.code =='40102' ,'GPA'] = 3.7
# df.loc[df.code =='40105' ,'GPA'] = 3.3
# df.loc[df.code =='40106' ,'GPA'] = 
# df.loc[df.code =='40501' ,'GPA'] = 
# df.loc[df.code =='40502' ,'GPA'] = 
# df.loc[df.code =='40503' ,'GPA'] = 
# df.loc[df.code =='40504' ,'GPA'] = 
# df.loc[df.code =='40505' ,'GPA'] =

# %%
df.to_csv('last updated data.csv',index=0)

# %% [markdown]
# The Courses I have taken

# %%
df_not_taken=df[df.if_taken==False]
df_taken=df[df.if_taken==True]
df_taken
# Out:
#      code                                            course  level  \
# 0   40102                           Engineering Mechanics 1    0.0
# 1   40105                           Production Technology 1    0.0
# 2   40106                           Engineering Mechanics 2    0.0
# 3   40501                        Engineering  Mathematics 1    0.0
# 4   40502                             Engineering Physics 1    0.0
# 5   40503                             Engineering Chemistry    0.0
# 6   40504                        Engineering  Mathematics 2    0.0
# 7   40505                             Engineering Physics 2    0.0
# 8   40101                                             CAD 1    0.0
# 9   40103                                             CAD 2    0.0
# 10  40104                               Engineering History    0.0
# 11  40144                                 Technical English    0.0
# 12  40108                           Engineering Mechanics 3    1.0
# ...

# %%
df_taken.hours.sum()
# Out:
# 95

# %% [markdown]
# The courses I have not taken

# %%
df_not_taken
# Out:
#      code                               course  level  \
# 14  40111                      Stress Analysis    1.0
# 24  40114   Computer-Aided mechanical Design 1    2.0
# 25  40115                 Theory of Viberation    2.0
# 29  40119   Computer-Aided mechanical Design 2    2.0
# 32  40206           Digital Control Systems NC    2.0
# 33  40207                    Electrical Motors    2.0
# 34  40208  Sensors and Measurement Instruments    2.0
# 36  40218                    Power Electronics    3.0
# 37  40131      Pneumatic and hydraulic systems    3.0
# 38  40134                Industrial Automation    3.0
# 39  40209                  Adapters and Relays    3.0
# 40  40130                           Simulation    3.0
# 41  40121               Mechatronics Systems 1    3.0
# 43  40129       Advanced Manufacturing Systems    3.0
# 45  40145               Industrial Engineering    4.0
# 46  40217               Artificial Inteligence    4.0
# ...

# %% [markdown]
# The total Number of hours taken for fundamental Engineering courses EF (required = 42)

# %%
FE_hours=df_taken.groupby('type')['hours'].sum()['Fundamental Engineering']
FE_hours
# Out:
# 27

# %% [markdown]
# Remaining hours for Fundamental Engineering

# %%
42-FE_hours
# Out:
# 15

# %% [markdown]
# Remaining courses for FE

# %%
df_not_taken[df_not_taken.type=='Fundamental Engineering']
# Out:
#      code                               course  level  \
# 14  40111                      Stress Analysis    1.0
# 25  40115                 Theory of Viberation    2.0
# 33  40207                    Electrical Motors    2.0
# 34  40208  Sensors and Measurement Instruments    2.0
# 36  40218                    Power Electronics    3.0
#
#                        type  hours  if_taken  prerequisite_1  prerequisite_2  \
# 14  Fundamental Engineering      3     False         40108.0             NaN
# 25  Fundamental Engineering      3     False         40108.0         40506.0
# 33  Fundamental Engineering      3     False         40108.0         40203.0
# 34  Fundamental Engineering      3     False         40203.0             NaN
# 36  Fundamental Engineering      3     False         40207.0             NaN
#
#     prerequisite_3  prerequisite_4  prerequisite_5  GPA
# 14             NaN             NaN             NaN  NaN
# 25         40508.0             NaN             NaN  NaN
# ...

# %% [markdown]
# The total Number of hours taken for Basic science courses  (required = 23)

# %%
BS_hours=df_taken.groupby('type')['hours'].sum()['Basic Science']
BS_hours
# Out:
# 23

# %% [markdown]
# Remaining hours for Basic Engineering

# %%
23-BS_hours
# Out:
# 0

# %% [markdown]
# Remaining courses for BS

# %%
df_not_taken[df_not_taken.type=='Basic Science']
# Out:
# Empty DataFrame
# Columns: [code, course, level, type, hours, if_taken, prerequisite_1, prerequisite_2, prerequisite_3, prerequisite_4, prerequisite_5, GPA]
# Index: []

# %% [markdown]
# The total Number of hours taken for General Engineering courses  (required = 47)

# %%
GE_hours=df_taken.groupby('type')['hours'].sum()['General Engineering']
GE_hours
# Out:
# 17

# %% [markdown]
# Remaining hours for General Engineering

# %%
47-GE_hours
# Out:
# 30

# %% [markdown]
# Remaining courses for GE

# %%
df_not_taken[df_not_taken.type=='General Engineering']
# Out:
#      code                           course  level                 type  hours  \
# 32  40206       Digital Control Systems NC    2.0  General Engineering      3
# 37  40131  Pneumatic and hydraulic systems    3.0  General Engineering      3
# 38  40134            Industrial Automation    3.0  General Engineering      3
# 39  40209              Adapters and Relays    3.0  General Engineering      3
# 41  40121           Mechatronics Systems 1    3.0  General Engineering      2
# 43  40129   Advanced Manufacturing Systems    3.0  General Engineering      2
# 45  40145           Industrial Engineering    4.0  General Engineering      3
# 46  40217           Artificial Inteligence    4.0  General Engineering      3
# 47  40135           Mechatronics Systems 2    4.0  General Engineering      2
# 49  40146               Quality Management    4.0  General Engineering      2
#
#     if_taken  prerequisite_1  prerequisite_2  prerequisite_3  prerequisite_4  \
# ...

# %% [markdown]
# The total Number of hours taken for computer applications courses  (required = 21)

# %%
CS_hours=df_taken.groupby('type')['hours'].sum()['computer applications']
CS_hours
# Out:
# 12

# %% [markdown]
# Remaining hours for computer applications

# %%
21-CS_hours
# Out:
# 9

# %% [markdown]
# Remaining courses for CS

# %%
df_not_taken[df_not_taken.type=='computer applications']
# Out:
#      code                              course  level                   type  \
# 24  40114  Computer-Aided mechanical Design 1    2.0  computer applications
# 29  40119  Computer-Aided mechanical Design 2    2.0  computer applications
# 40  40130                          Simulation    3.0  computer applications
#
#     hours  if_taken  prerequisite_1  prerequisite_2  prerequisite_3  \
# 24      3     False         40103.0         40111.0         40113.0
# 29      3     False         40114.0             NaN             NaN
# 40      3     False         40108.0         40109.0         40112.0
#
#     prerequisite_4  prerequisite_5  GPA
# 24             NaN             NaN  NaN
# 29             NaN             NaN  NaN
# 40         40508.0         40201.0  NaN

# %% [markdown]
# The total Number of hours taken for Elective course  (required = 8)

# %%
EC_hours=df_taken.groupby('type')['hours'].sum()['Elective course']
EC_hours
# Out:
# 6

# %% [markdown]
# Remaining hours for Elective course

# %%
8-EC_hours
# Out:
# 2

# %% [markdown]
# Remaining courses for EC

# %%
df_not_taken[df_not_taken.type=='Elective course']
# Out:
#      code             course  level             type  hours  if_taken  \
# 52  50001  Feasibility study    NaN  Elective course      2     False
#
#     prerequisite_1  prerequisite_2  prerequisite_3  prerequisite_4  \
# 52             NaN             NaN             NaN             NaN
#
#     prerequisite_5  GPA
# 52             NaN  NaN

# %% [markdown]
# The total Number of hours taken for Social Science courses  (required = 18)

# %%
SS_hours=df_taken.groupby('type')['hours'].sum()['Social Science']
SS_hours
# Out:
# 10

# %% [markdown]
# Remaining hours for Social Science

# %%
18-SS_hours
# Out:
# 8

# %% [markdown]
# Remaining courses for SS

# %%
df_not_taken[df_not_taken.type=='Social Science']
# Out:
# Empty DataFrame
# Columns: [code, course, level, type, hours, if_taken, prerequisite_1, prerequisite_2, prerequisite_3, prerequisite_4, prerequisite_5, GPA]
# Index: []

# %% [markdown]
# # GPA Clculation

# %% [markdown]
# Gathering the courses with final exams(GPA) in a file named (GPA) and displaying them

# %%
GPA = df[df.GPA >0]

# %%
GPA
# Out:
#      code                                            course  level  \
# 0   40102                           Engineering Mechanics 1    0.0
# 1   40105                           Production Technology 1    0.0
# 2   40106                           Engineering Mechanics 2    0.0
# 3   40501                        Engineering  Mathematics 1    0.0
# 4   40502                             Engineering Physics 1    0.0
# 5   40503                             Engineering Chemistry    0.0
# 6   40504                        Engineering  Mathematics 2    0.0
# 7   40505                             Engineering Physics 2    0.0
# 8   40101                                             CAD 1    0.0
# 9   40103                                             CAD 2    0.0
# 10  40104                               Engineering History    0.0
# 11  40144                                 Technical English    0.0
# 12  40108                           Engineering Mechanics 3    1.0
# ...

# %%
GPA.hours.sum()
# Out:
# 66

# %%
sum_hours=GPA.hours.sum()
GPA['GPA x hours']=GPA['hours']*GPA['GPA']
GPA['GPA x hours'].sum()/sum_hours
# Out:
# <ipython-input-217-145537370f43>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GPA['GPA x hours']=GPA['hours']*GPA['GPA']
# 3.8075757575757576
